# %% [markdown]
# # Case de Análise de Dados no Pandas!
#
# Iremos usar o banco de dados [Online Retail.xlsx](https://archive.ics.uci.edu/ml/datasets/Online+Retail), disponível no [Repositório de Dados para Machine Learning da UCI](https://archive.ics.uci.edu/ml/index.php). Para efeitos didáticos, eu fiz uma transformação no banco de dados para incluir a coluna `region`, que contém o nome do país assim como do continente.
#
# ![title](https://raw.githubusercontent.com/amauri-ti/labdata/04739413840b9e11d8acb3a1de37646648eee4d9/imgs/uci-logo.png)

# %% [markdown]
# ### Importando as bibliotecas necessárias e o banco de dados

# %%
import numpy as np
import pandas as pd
from datetime import date
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = spark.read.csv("/FileStore/tables/retail-2.csv", header=True, sep=';')
df = df.toPandas()

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(dbutils.fs.ls('/FileStore/tables/'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Companhia_MB-1.txt</td><td>Companhia_MB-1.txt</td><td>1710</td><td>1682425583000</td></tr><tr><td>dbfs:/FileStore/tables/Companhia_MB.txt</td><td>Companhia_MB.txt</td><td>1710</td><td>1682345736000</td></tr><tr><td>dbfs:/FileStore/tables/retail-1.csv</td><td>retail-1.csv</td><td>46123660</td><td>1682009478000</td></tr><tr><td>dbfs:/FileStore/tables/retail-2.csv</td><td>retail-2.csv</td><td>46123660</td><td>1682617786000</td></tr><tr><td>dbfs:/FileStore/tables/retail.csv</td><td>retail.csv</td><td>46123658</td><td>1682002987000</td></tr></tbody></table></div>

# %% [markdown]
# #### Significado das colunas:
#
# * `invoice_no`: número do pedido
# * `stock_code`: número único que caracteriza o item/produto (SKU)
# * `description`: descrição/nome do produto
# * `quantity`: quantidade do produto vendida
# * `invoice_date`: data em que o pedido foi realizado
# * `unit_price`: preço unitário
# * `customer_id`: identificador único do cliente
# * `region`: região de onde o cliente realizou a compra

# %% [markdown]
# # Operações básicas de dados no Pandas

# %% [markdown]
# ## 1. Selecionando colunas
#
# Existem 2 formas de selecionar colunas no Pandas: a primeira é usando o `parênteses` e a segunda usando o método `filter()`.

# %%
df[['stock_code', 'unit_price']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>2,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>71053</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84406B</td>
#       <td>2,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84029G</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>84029E</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>22613</td>
#       <td>0,85</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>22899</td>
#       <td>2,1</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>23254</td>
#       <td>4,15</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>23255</td>
#       <td>4,15</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>22138</td>
#       <td>4,95</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 2 columns</p>
# </div>

# %%
df.filter(['stock_code', 'unit_price'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>2,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>71053</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84406B</td>
#       <td>2,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84029G</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>84029E</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>22613</td>
#       <td>0,85</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>22899</td>
#       <td>2,1</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>23254</td>
#       <td>4,15</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>23255</td>
#       <td>4,15</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>22138</td>
#       <td>4,95</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 2 columns</p>
# </div>

# %%
df.filter(like='id')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>17850</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>12680</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>12680</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 1 columns</p>
# </div>

# %%
toy_df = pd.DataFrame({'pedido_id': [1, 1, 2, 3, 3], 
                       'produto_id': [251, 985, 390, 204, 985], 
                       'descricao': ['carro', 'boneca', 'celular', 'caderno', 'boneca'], 
                       'data_compra': ['2020-03-01', '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-03'], 
                       'data_entrega': ['2020-03-02', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-04'], 
                       'valor_item': [25000, 30, 2000, 15, 30], 
                       'quantidade': [1, 1, 1, 2, 3]})
toy_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pedido_id</th>
#       <th>produto_id</th>
#       <th>descricao</th>
#       <th>data_compra</th>
#       <th>data_entrega</th>
#       <th>valor_item</th>
#       <th>quantidade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>251</td>
#       <td>carro</td>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#       <td>25000</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>985</td>
#       <td>boneca</td>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#       <td>30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>390</td>
#       <td>celular</td>
#       <td>2020-03-02</td>
#       <td>2020-03-03</td>
#       <td>2000</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>204</td>
#       <td>caderno</td>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#       <td>15</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>985</td>
#       <td>boneca</td>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#       <td>30</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
toy_df.shape
# Out:
# Out[101]: (5, 7)

# %%
toy_df.filter(like='data')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data_compra</th>
#       <th>data_entrega</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-03-01</td>
#       <td>2020-03-02</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-03-02</td>
#       <td>2020-03-03</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
toy_df.filter(like='id')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pedido_id</th>
#       <th>produto_id</th>
#       <th>quantidade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>251</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>985</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>390</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>204</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>985</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 2. Filtros
#
# Também existem duas formas de realizar filtros no Pandas: uma com `parênteses` e outra com o método `query()`.

# %%
df[df['invoice_no'] == '536368']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.query('invoice_no == "536368"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Filtrando com duas condições
#
# Condição `and`

# %%
df[(df['invoice_no'] == '536368') & (df['stock_code'] == '22960')]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.query('invoice_no == "536368" and stock_code == "22960"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Condição `or`

# %%
df[(df['invoice_no'] == '536368') | (df['stock_code'] == '22960')]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>170</th>
#       <td>536385</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 09:56</td>
#       <td>4,25</td>
#       <td>17420</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>539091</th>
#       <td>581433</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>08/12/2011 15:54</td>
#       <td>4,25</td>
#       <td>14911</td>
#       <td>EIRE</td>
#     </tr>
#     <tr>
#       <th>539731</th>
#       <td>581439</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>3</td>
#       <td>08/12/2011 16:30</td>
#       <td>8,29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>539954</th>
#       <td>581451</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>08/12/2011 17:57</td>
#       <td>4,25</td>
#       <td>17144</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541049</th>
#       <td>581492</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>2</td>
#       <td>09/12/2011 10:03</td>
#       <td>8,29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541468</th>
#       <td>581498</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>5</td>
#       <td>09/12/2011 10:26</td>
#       <td>8,29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# <p>1232 rows × 8 columns</p>
# </div>

# %%
df.query('invoice_no == "536368" or stock_code == "22960"')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>536368</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,25</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>536368</td>
#       <td>22913</td>
#       <td>RED COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>536368</td>
#       <td>22912</td>
#       <td>YELLOW COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>536368</td>
#       <td>22914</td>
#       <td>BLUE COAT RACK PARIS FASHION</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>4,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>170</th>
#       <td>536385</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>01/12/2010 09:56</td>
#       <td>4,25</td>
#       <td>17420</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>539091</th>
#       <td>581433</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>08/12/2011 15:54</td>
#       <td>4,25</td>
#       <td>14911</td>
#       <td>EIRE</td>
#     </tr>
#     <tr>
#       <th>539731</th>
#       <td>581439</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>3</td>
#       <td>08/12/2011 16:30</td>
#       <td>8,29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>539954</th>
#       <td>581451</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>6</td>
#       <td>08/12/2011 17:57</td>
#       <td>4,25</td>
#       <td>17144</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541049</th>
#       <td>581492</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>2</td>
#       <td>09/12/2011 10:03</td>
#       <td>8,29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>541468</th>
#       <td>581498</td>
#       <td>22960</td>
#       <td>JAM MAKING SET WITH JARS</td>
#       <td>5</td>
#       <td>09/12/2011 10:26</td>
#       <td>8,29</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# <p>1232 rows × 8 columns</p>
# </div>

# %% [markdown]
# ## 3. Criando novas colunas
#
# Existem duas formas de criar colunas com o Pandas: uma com `parênteses` e outra usando o método `assign()`.

# %%
df['total_price'] = df['quantity'] + df['unit_price']

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>62,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>82,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.drop('total_price', axis=1, inplace=True)

# %%
df.assign(total_price = df['quantity'] + df['unit_price']).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>62,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>82,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# O método `assign()` não modifica a tabela inplace. O que o torna uma boa opção para validar a nova coluna criada antes de efetivamente adicioná-la na tabela.

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Para salvar a coluna de fato, devemos atribuir a operação para uma tabela.

# %%
df = df.assign(total_price = df['quantity'] + df['unit_price'])

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>62,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>82,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>63,39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.drop('total_price', axis=1, inplace=True)

# %% [markdown]
# ## 4. Ordenando colunas
#
# Aqui, existem apenas um método: `sort_values()`.

# %%
df.sort_values('invoice_date').head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>77641</th>
#       <td>542776</td>
#       <td>21485</td>
#       <td>RETROSPOT HEART HOT WATER BOTTLE</td>
#       <td>3</td>
#       <td>01/02/2011 08:23</td>
#       <td>4,95</td>
#       <td>15240</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>77640</th>
#       <td>542776</td>
#       <td>21218</td>
#       <td>RED SPOTTY BISCUIT TIN</td>
#       <td>6</td>
#       <td>01/02/2011 08:23</td>
#       <td>3,75</td>
#       <td>15240</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>77639</th>
#       <td>542776</td>
#       <td>17021</td>
#       <td>NAMASTE SWAGAT INCENSE</td>
#       <td>36</td>
#       <td>01/02/2011 08:23</td>
#       <td>0,3</td>
#       <td>15240</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>77638</th>
#       <td>542776</td>
#       <td>22083</td>
#       <td>PAPER CHAIN KIT RETROSPOT</td>
#       <td>12</td>
#       <td>01/02/2011 08:23</td>
#       <td>2,95</td>
#       <td>15240</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>77637</th>
#       <td>542776</td>
#       <td>22835</td>
#       <td>HOT WATER BOTTLE I AM SO POORLY</td>
#       <td>4</td>
#       <td>01/02/2011 08:23</td>
#       <td>4,65</td>
#       <td>15240</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_values('invoice_date', ascending=False).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>431672</th>
#       <td>573734</td>
#       <td>72818</td>
#       <td>check</td>
#       <td>-26</td>
#       <td>31/10/2011 17:19</td>
#       <td>0</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>431671</th>
#       <td>573726</td>
#       <td>72817</td>
#       <td>check</td>
#       <td>-67</td>
#       <td>31/10/2011 17:18</td>
#       <td>0</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>431670</th>
#       <td>573695</td>
#       <td>23397</td>
#       <td>FOOT STOOL HOME SWEET HOME</td>
#       <td>4</td>
#       <td>31/10/2011 17:13</td>
#       <td>9,95</td>
#       <td>15023</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>431669</th>
#       <td>573695</td>
#       <td>23543</td>
#       <td>WALL ART KEEP CALM</td>
#       <td>1</td>
#       <td>31/10/2011 17:13</td>
#       <td>8,25</td>
#       <td>15023</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>431668</th>
#       <td>573695</td>
#       <td>23407</td>
#       <td>SET OF 2 TRAYS HOME SWEET HOME</td>
#       <td>2</td>
#       <td>31/10/2011 17:13</td>
#       <td>9,95</td>
#       <td>15023</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 5. Aggregações
#
# No Pandas podemos criar agregações de duas formas: em uma coluna ou em grupos.
#
# ### Agregações em uma coluna

# %%
df['invoice_date'].min()
# Out:
# Out[121]: '01/02/2011 08:23'

# %%
df['invoice_date'].max()
# Out:
# Out[122]: '31/10/2011 17:19'

# %%
df.agg({'invoice_date': ['min', 'max']})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>min</th>
#       <td>01/02/2011 08:23</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>31/10/2011 17:19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Agregações no método `groupby()`

# %%
df.groupby('invoice_no').agg(n=('stock_code', 'count')).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 2 columns</p>
# </div>

# %% [markdown]
# ## 6. Combinando as operações

# %% [markdown]
# Limpando os nossos dados. Pedidos com começam com a letra `C` foram cancelados, logo devem ser retirados da base de dados.
# Também temos pedidos com quantidades negativas, que significa que ou foram cancelados ou estornados.

# %%
#df = (
#    df
#    .assign(start_with_c = lambda x: x['invoice_no'].str.startswith('C'))
#    .query('start_with_c == False')
#    .query('quantity >= 0')
#)

# %% [markdown]
# ##### Realize uma 'query' que retorne os top 10 pedidos com mais itens.

# %%
df.groupby('invoice_no').agg(n=('stock_code', 'count')).reset_index().sort_values('n', ascending=False).head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Traga a data em que o pedido foi realizado

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>31/10/2011 14:41</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>08/12/2011 09:28</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>09/12/2011 10:03</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>05/12/2011 17:24</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>29/06/2011 15:58</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>30/11/2011 15:13</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>08/12/2011 09:20</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>06/12/2010 16:57</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>05/12/2011 17:28</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>09/12/2010 14:09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Crie uma coluna apenas com a data --> valendo 1 ponto
# ### -> retornamos segunda

# %%
#import datetime as dt
from datetime import date

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(date = date.today())
    .assign(date2 = date.today())
    .assign(date3 = date(2023, 4, 24))
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#       <th>date</th>
#       <th>date2</th>
#       <th>date3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>31/10/2011 14:41</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>08/12/2011 09:28</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>09/12/2011 10:03</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>05/12/2011 17:24</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>29/06/2011 15:58</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>30/11/2011 15:13</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>08/12/2011 09:20</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>06/12/2010 16:57</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>05/12/2011 17:28</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>09/12/2010 14:09</td>
#       <td>2023-05-03</td>
#       <td>2023-05-03</td>
#       <td>2023-04-24</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8</td>
#       <td>01/12/2010 08:26</td>
#       <td>2,75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6</td>
#       <td>01/12/2010 08:26</td>
#       <td>3,39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>581587</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>12</td>
#       <td>09/12/2011 12:50</td>
#       <td>0,85</td>
#       <td>12680</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>581587</td>
#       <td>22899</td>
#       <td>CHILDREN'S APRON DOLLY GIRL</td>
#       <td>6</td>
#       <td>09/12/2011 12:50</td>
#       <td>2,1</td>
#       <td>12680</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>581587</td>
#       <td>23254</td>
#       <td>CHILDRENS CUTLERY DOLLY GIRL</td>
#       <td>4</td>
#       <td>09/12/2011 12:50</td>
#       <td>4,15</td>
#       <td>12680</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>581587</td>
#       <td>23255</td>
#       <td>CHILDRENS CUTLERY CIRCUS PARADE</td>
#       <td>4</td>
#       <td>09/12/2011 12:50</td>
#       <td>4,15</td>
#       <td>12680</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>581587</td>
#       <td>22138</td>
#       <td>BAKING SET 9 PIECE RETROSPOT</td>
#       <td>3</td>
#       <td>09/12/2011 12:50</td>
#       <td>4,95</td>
#       <td>12680</td>
#       <td>France</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 8 columns</p>
# </div>

# %% [markdown]
# No pandas, assim como no SQL, não conseguimos referenciar uma coluna que acabou de ser criada. Para conseguirmos fazer isso, podemos usar funções lambda!
#
# DESAFIO VALENDO 1 PONTO! CASA!

# %%
df = df.assign(Date = lambda x: pd.to_datetime(x['invoice_date']))

df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>536365</td>
#       <td>22752</td>
#       <td>SET 7 BABUSHKA NESTING BOXES</td>
#       <td>2.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>7.65</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>536365</td>
#       <td>21730</td>
#       <td>GLASS STAR FROSTED T-LIGHT HOLDER</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>4.25</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>25.50</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>536366</td>
#       <td>22633</td>
#       <td>HAND WARMER UNION JACK</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:28</td>
#       <td>1.85</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>11.10</td>
#       <td>2010-01-12 08:28:00</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>536366</td>
#       <td>22632</td>
#       <td>HAND WARMER RED POLKA DOT</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:28</td>
#       <td>1.85</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>11.10</td>
#       <td>2010-01-12 08:28:00</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>536367</td>
#       <td>84879</td>
#       <td>ASSORTED COLOUR BIRD ORNAMENT</td>
#       <td>32.0</td>
#       <td>01/12/2010 08:34</td>
#       <td>1.69</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#       <td>54.08</td>
#       <td>2010-01-12 08:34:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         first_date = ('Date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>first_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31 14:41:00</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-08-12 09:28:00</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-09-12 10:03:00</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-05-12 17:24:00</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29 15:58:00</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30 15:13:00</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-08-12 09:20:00</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-06-12 16:57:00</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-05-12 17:28:00</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-09-12 14:09:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# A coluna `datetime` não é do time datetime. Ela é do tipo `object`.

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .dtypes
)
# Out:
# Out[131]: invoice_no    object
# n              int64
# datetime      object
# dtype: object

# %% [markdown]
# Então, para resolvermos o problema temos que transformar o tipo da coluna para datetime e só depois conseguiremos performar a operação desejada.

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .dtypes
)
# Out:
# Out[132]: invoice_no            object
# n                      int64
# datetime      datetime64[ns]
# dtype: object

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>datetime</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31 14:41:00</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-08-12 09:28:00</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-09-12 10:03:00</td>
#       <td>2011-09-12</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-05-12 17:24:00</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29 15:58:00</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30 15:13:00</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-08-12 09:20:00</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-06-12 16:57:00</td>
#       <td>2010-06-12</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-05-12 17:28:00</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-09-12 14:09:00</td>
#       <td>2010-09-12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Agora, vamos dropar a coluna `datetime`.
#
# Jeito 1:

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
    .drop('datetime', axis=1)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-09-12</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-06-12</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-09-12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Jeito 2:

# %%
(
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
    .filter(['invoice_no', 'n', 'date'])
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-09-12</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-06-12</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-09-12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
top_10_invoice_df = (
    df
    .groupby('invoice_no')
    .agg(n        = ('stock_code', 'count'), 
         datetime = ('invoice_date', 'first'))
    .reset_index()
    .sort_values('n', ascending=False)
    .head(10)
    .assign(datetime = lambda x: pd.to_datetime(x['datetime']))
    .assign(date = lambda x: x['datetime'].dt.date)
    .filter(['invoice_no', 'n', 'date'])
)

# %%
top_10_invoice_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18141</th>
#       <td>573585</td>
#       <td>1114</td>
#       <td>2011-10-31</td>
#     </tr>
#     <tr>
#       <th>21897</th>
#       <td>581219</td>
#       <td>749</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>22032</th>
#       <td>581492</td>
#       <td>731</td>
#       <td>2011-09-12</td>
#     </tr>
#     <tr>
#       <th>21645</th>
#       <td>580729</td>
#       <td>721</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>10713</th>
#       <td>558475</td>
#       <td>705</td>
#       <td>2011-06-29</td>
#     </tr>
#     <tr>
#       <th>21164</th>
#       <td>579777</td>
#       <td>687</td>
#       <td>2011-11-30</td>
#     </tr>
#     <tr>
#       <th>21895</th>
#       <td>581217</td>
#       <td>676</td>
#       <td>2011-08-12</td>
#     </tr>
#     <tr>
#       <th>576</th>
#       <td>537434</td>
#       <td>675</td>
#       <td>2010-06-12</td>
#     </tr>
#     <tr>
#       <th>21646</th>
#       <td>580730</td>
#       <td>662</td>
#       <td>2011-05-12</td>
#     </tr>
#     <tr>
#       <th>881</th>
#       <td>538071</td>
#       <td>652</td>
#       <td>2010-09-12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Vamos fazer um gráfico de barras

# %%
top_10_invoice_df.plot(kind='bar', x='invoice_no', y='n', rot=45);

# %%
import seaborn as sns


sns.barplot(data=top_10_invoice_df, x='invoice_no', y='n');

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.barplot(data=top_10_invoice_df, x='invoice_no', y='n', ax=ax, color='green');
ax.set_ylabel('Qtde de items no pedido', fontsize=13);
ax.set_xlabel('Pedido', fontsize=13);
ax.set_title('Top 10 Pedidos com mais Items', fontsize=15);

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))

sns.barplot(data=top_10_invoice_df, x='invoice_no', y='n', ax=ax, color='green');
ax.set_ylabel('Qtde de items no pedido', fontsize=13);
ax.set_xlabel('Pedido', fontsize=13);
ax.set_title('Top 10 Pedidos com mais Items', fontsize=15);

# %% [markdown]
# ### Vamos fazer um boxplot do preço total do pedido
#
# valendo 0,5!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  object
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  object
#  6   customer_id   406829 non-null  object
#  7   region        541909 non-null  object
# dtypes: object(8)
# memory usage: 33.1+ MB

# %%
df['quantity'] = df['quantity'].astype(float)

# %%
df['unit_price'] = df['unit_price'].str.replace(',','.')

# %%
df['unit_price'] = df['unit_price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  float64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  object
#  7   region        541909 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 33.1+ MB

# %%
df['total_price'] = df['quantity'] * df['unit_price']
df['total_price']
# Out:
# Out[147]: 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: total_price, Length: 541909, dtype: float64

# %%
df_pedido_agrupado = df[['invoice_no', 'total_price']].groupby('invoice_no').sum('total_price').reset_index()
df_pedido_agrupado
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>139.12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>22.20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>278.73</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>70.05</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>17.85</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>-168469.60</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>-32.53</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>-224.69</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>-54.75</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>-7.50</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 2 columns</p>
# </div>

# %%
plt.figure(figsize=(15,5))
gf_totalpedidos = sns.boxplot(y=df_pedido_agrupado['total_price'], linewidth=5)
plt.title("Boxplot - Total Pedidos", loc="center", fontsize=18)
plt.ylabel("Valor Pedidos")
plt.show(gf_totalpedidos)

# %%
revenue_by_invoice_df = (
    df
    .assign(preco = lambda x: x['quantity'] * x['unit_price'])
    .groupby('invoice_no')
    .agg(revenue = ('total_price', 'sum'))
    .reset_index()
)
revenue_by_invoice_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>139.12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>22.20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>278.73</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>70.05</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>17.85</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>-168469.60</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>-32.53</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>-224.69</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>-54.75</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>-7.50</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 2 columns</p>
# </div>

# %%
fig, ax = plt.subplots(figsize=(10, 4))

sns.boxplot(data=revenue_by_invoice_df, x='revenue', ax=ax);

# %% [markdown]
# Vamos fazer o mesmo boxplot, mas para cada mês
#
# valendo 0,5!

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  float64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  object
#  7   region        541909 non-null  object
#  8   total_price   541909 non-null  float64
#  9   Date          541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 41.3+ MB

# %%
df['Mes'] = df['Date'].dt.month

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#       <th>total_price</th>
#       <th>Date</th>
#       <th>Mes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>85123A</td>
#       <td>WHITE HANGING HEART T-LIGHT HOLDER</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>2.55</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>15.30</td>
#       <td>2010-01-12 08:26:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536365</td>
#       <td>71053</td>
#       <td>WHITE METAL LANTERN</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536365</td>
#       <td>84406B</td>
#       <td>CREAM CUPID HEARTS COAT HANGER</td>
#       <td>8.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>2.75</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>22.00</td>
#       <td>2010-01-12 08:26:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536365</td>
#       <td>84029G</td>
#       <td>KNITTED UNION FLAG HOT WATER BOTTLE</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536365</td>
#       <td>84029E</td>
#       <td>RED WOOLLY HOTTIE WHITE HEART.</td>
#       <td>6.0</td>
#       <td>01/12/2010 08:26</td>
#       <td>3.39</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#       <td>20.34</td>
#       <td>2010-01-12 08:26:00</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  float64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  object
#  7   region        541909 non-null  object
#  8   total_price   541909 non-null  float64
#  9   Date          541909 non-null  datetime64[ns]
#  10  Mes           541909 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 45.5+ MB

# %%
df_agrupado_mes = df.groupby('Mes').sum('total_price').filter(['Mes', 'total_price']).reset_index()
df_agrupado_mes
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Mes</th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>666383.670</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>588718.820</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>757679.970</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>660149.571</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>765153.270</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>799112.520</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>888950.281</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>759822.560</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>1045087.582</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>989257.070</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>1297606.420</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>529826.200</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_no    541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  float64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  object
#  7   region        541909 non-null  object
#  8   total_price   541909 non-null  float64
#  9   Date          541909 non-null  datetime64[ns]
#  10  Mes           541909 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 45.5+ MB

# %%
df_agrupado_mes2 = (
                    df[['invoice_no', 'total_price', 'Date']]
                    .groupby('invoice_no')
                    .agg(soma=('total_price', 'sum'),
                         Data=('Date', 'first'))
                    .reset_index())
df_agrupado_mes2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>soma</th>
#       <th>Data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>139.12</td>
#       <td>2010-01-12 08:26:00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>22.20</td>
#       <td>2010-01-12 08:28:00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>278.73</td>
#       <td>2010-01-12 08:34:00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>70.05</td>
#       <td>2010-01-12 08:34:00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>17.85</td>
#       <td>2010-01-12 08:35:00</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>-168469.60</td>
#       <td>2011-09-12 09:27:00</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>-32.53</td>
#       <td>2011-09-12 09:57:00</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>-224.69</td>
#       <td>2011-09-12 10:28:00</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>-54.75</td>
#       <td>2011-09-12 11:57:00</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>-7.50</td>
#       <td>2011-09-12 11:58:00</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 3 columns</p>
# </div>

# %%
df_agrupado_mes2['Mes']= df_agrupado_mes2['Data'].dt.month
df_agrupado_mes2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>soma</th>
#       <th>Data</th>
#       <th>Mes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>139.12</td>
#       <td>2010-01-12 08:26:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>22.20</td>
#       <td>2010-01-12 08:28:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>278.73</td>
#       <td>2010-01-12 08:34:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>70.05</td>
#       <td>2010-01-12 08:34:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>17.85</td>
#       <td>2010-01-12 08:35:00</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>-168469.60</td>
#       <td>2011-09-12 09:27:00</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>-32.53</td>
#       <td>2011-09-12 09:57:00</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>-224.69</td>
#       <td>2011-09-12 10:28:00</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>-54.75</td>
#       <td>2011-09-12 11:57:00</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>-7.50</td>
#       <td>2011-09-12 11:58:00</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 4 columns</p>
# </div>

# %%
df_agrupado_mes2 = df_agrupado_mes2.drop('Data', axis=1)
df_agrupado_mes2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>soma</th>
#       <th>Mes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>139.12</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>22.20</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>278.73</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>70.05</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>17.85</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>-168469.60</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>-32.53</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>-224.69</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>-54.75</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>-7.50</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 3 columns</p>
# </div>

# %%
plt.figure(figsize=(15,5))
gf_total_mes = sns.boxplot(data=df_agrupado_mes2, x='Mes', y='soma', linewidth=5)
plt.title("Boxplot - Total Pedidos x Mes", loc="center", fontsize=18)
plt.ylabel("Valor Pedidos")
plt.show(gf_total_mes)

# %% [markdown]
# # Vamos calcular a receita por país

# %%
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df[['country', 'continent']] = df['region'].str.split(n=1, expand=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ### Podemos criar uma função

# %%
def separate_col(data, col, into):
    df = data.copy()
    df[into] = df[col].str.split(', ', expand=True)
    return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df = df.drop(['country', 'continent'], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#separate_col(df, col='region', into=['country', 'continent'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#df.pipe(separate_col, col='region', into=['country', 'continent'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Vamos generalizar a nossa função! Vamos incluir o argumento `sep` e `keep`.

# %%
def separate_col(data, col, into, sep=', ', keep=True):
    df = data.copy()
    df[into] = df[col].str.split(sep, expand=True)
    
    if keep:
        return df
    else:
        df = df.drop(col, axis=1)
        return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.pipe(separate_col, col='region', into=['country', 'continent'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.pipe(separate_col, col='region', into=['country', 'continent'], keep=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ### Retorne os 10 países com as maiores receitas.

# %%
top10_revenue_by_country_df = (
    df
    .pipe(separate_col, col='region', into=['country', 'continent'], keep=False)
    .assign(total_price = lambda x: x['quantity'] * x['unit_price'])
    .groupby('country')
    .agg(revenue = ('total_price', 'sum'))
    .reset_index()
    .sort_values('revenue', ascending=False)
    .head(10)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
top10_revenue_by_country_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.barplot(data=top10_revenue_by_country_df, y='country', x='revenue', ax=ax, color='green');
ax.set_ylabel('Country', fontsize=13);
ax.set_xlabel('Revenu', fontsize=13);
ax.set_title('Revenue by Country', fontsize=15);
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ### Vez de vocês! Façam o mesmo, mas para os continentes!

# %% [markdown]
# ### Vamos calcular, para cada cliente, o seu RFV

# %%
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from datetime import datetime, date

rfv_df = (
    df
    .assign(total_price=df['quantity'] + df['unit_price'])
    .groupby(['customer_id'])
    .agg(revenue   = ('total_price', 'sum'), 
         frequency = ('invoice_no', 'count'), 
         last_shop = ('invoice_date', 'max'))
    .reset_index()
    .assign(last_shop = lambda x: pd.to_datetime(x['last_shop'], infer_datetime_format=True))
    .assign(ref_date = datetime.strptime('2012-01-01', '%Y-%m-%d'))
    .assign(recency = lambda x: (x['ref_date'] - x['last_shop']).dt.days)
    .filter(['ref_date', 'customer_id', 'revenue', 'frequency', 'recency'])
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
rfv_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
